# %%
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import transforms, datasets

# %%
if torch.cuda.is_available():
    DEVICE = torch.device('cuda')
else:
    DEVICE = torch.device('cpu')
    
print('Using PyTorch version:', torch.__version__, ' Device:', DEVICE)
# Out:
# Using PyTorch version: 1.7.0  Device: cuda

# %%
BATCH_SIZE = 32
EPOCHS = 20

# %%
train_dataset = datasets.CIFAR10(root = "./data/CIFAR_10",
                                train = True,
                                download = True,
                                transform = transforms.Compose([
                                    transforms.RandomHorizontalFlip(),
                                    transforms.ToTensor(),
                                    transforms.Normalize((0.5, 0.5, 0.5),
                                                         (0.5, 0.5, 0.5))
                                ]))

test_dataset = datasets.CIFAR10(root = "./data/CIFAR_10",
                               train = False,
                               transform = transforms.Compose([
                                   transforms.RandomHorizontalFlip(),
                                   transforms.ToTensor(),
                                   transforms.Normalize((0.5, 0.5, 0.5),
                                                       (0.5, 0.5, 0.5))
                               ]))

train_loader = torch.utils.data.DataLoader(dataset = train_dataset,
                                          batch_size = BATCH_SIZE,
                                          shuffle = True)

test_loader = torch.utils.data.DataLoader(dataset = test_dataset,
                                         batch_size = BATCH_SIZE,
                                         shuffle = False)
# Out:
# Files already downloaded and verified

# %%
for(X_train, Y_train) in train_loader:
    print('X_train:', X_train.size(), 'type:', X_train.type())
    print('Y_train:', Y_train.size(), 'type:', Y_train.type())
    break
# Out:
# X_train: torch.Size([32, 3, 32, 32]) type: torch.FloatTensor
# Y_train: torch.Size([32]) type: torch.LongTensor

# %%
pltsize = 1
plt.figure(figsize=(10 * pltsize, pltsize))

for i in range(10):
    plt.subplot(1, 10, i + 1)
    plt.axis('off')
    plt.imshow(np.transpose(X_train[i],(1, 2, 0)))
    plt.title('Class: ' + str(Y_train[i].item()))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
class BasicBlock(nn.Module):
    def __init__(self, in_planes, planes, stride = 1):
        super(BasicBlock, self).__init__()
        self.conv1 =  nn.Conv2d(in_planes, planes,
                                kernel_size = 3,
                                stride = stride,
                                padding = 1,
                                bias = False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes,
                                kernel_size = 3,
                                stride = 1,
                                padding = 1,
                                bias = False)
        self.bn2 = nn.BatchNorm2d(planes)
        
        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != planes:
            self.shortcut = nn.Sequential(
            nn.Conv2d(in_planes, planes,
                     kernel_size = 1,
                     stride = stride,
                     bias = False),
            nn.BatchNorm2d(planes))
        
    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out

class ResNet(nn.Module):
    def __init__(self, num_classes = 10):
        super(ResNet, self).__init__()
        self.in_planes = 16
        
        self.conv1 = nn.Conv2d(3, 16,
                              kernel_size = 3,
                              stride = 1,
                              padding = 1,
                              bias = False)
        self.bn1 = nn.BatchNorm2d(16)
        self.layer1 = self._make_layer(16, 2, stride = 1)
        self.layer2 = self._make_layer(32, 2, stride = 2)
        self.layer3 = self._make_layer(64, 2, stride = 2)
        self.linear = nn.Linear(64, num_classes)
        
    def _make_layer(self, planes, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(BasicBlock(self.in_planes, planes, stride))
            self.in_planes = planes
        return nn.Sequential(*layers)
    
    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = F.avg_pool2d(out, 8)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out

# %%
model = ResNet().to(DEVICE)
optimizer = torch.optim.Adam(model.parameters(), lr = 0.001)
criterion = nn.CrossEntropyLoss()

print(model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(16, 32, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(32, 64, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (linear): Linear(in_features=64, out_features=10, bias=True)
# )

# %%
def train(model, train_loader, optimizer, log_interval):
    model.train()
    for batch_idx, (image, label) in enumerate(train_loader):
        image = image.to(DEVICE)
        label = label.to(DEVICE)
        optimizer.zero_grad()
        output = model(image)
        loss = criterion(output, label)
        loss.backward()
        optimizer.step()
        
        if batch_idx % log_interval == 0:
            print("Train Epoch: {} [{}/{}({:.0f}%)]\tTrain Loss: {:.6f}".format(
            Epoch, batch_idx * len(image),
            len(train_loader.dataset), 100. * batch_idx / len(train_loader), loss.item()))

# %%
def evaluate(model, test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    
    with torch.no_grad():
        for image, label in test_loader:
            image = image.to(DEVICE)
            label = label.to(DEVICE)
            output = model(image)
            test_loss += criterion(output, label).item()
            prediction = output.max(1, keepdim = True)[1]
            correct += prediction.eq(label.view_as(prediction)).sum().item()
    test_loss /= len(test_loader.dataset)
    test_accuracy = 100. * correct / len(test_loader.dataset)
    return test_loss, test_accuracy

# %%
for Epoch in range(1, EPOCHS + 1):
    train(model, train_loader, optimizer, log_interval = 200)
    test_loss, test_accuracy = evaluate(model, test_loader)
    print("\n[EPOCH: {}], \tTest Loss: {:.4f}, \tTest Accuracy: {:.2f} % \n".format(
    Epoch, test_loss, test_accuracy))
# Out:
# Train Epoch: 1 [0/50000(0%)]	Train Loss: 2.449908
# Train Epoch: 1 [6400/50000(13%)]	Train Loss: 1.733035
# Train Epoch: 1 [12800/50000(26%)]	Train Loss: 1.477278
# Train Epoch: 1 [19200/50000(38%)]	Train Loss: 1.721989
# Train Epoch: 1 [25600/50000(51%)]	Train Loss: 1.044314
# Train Epoch: 1 [32000/50000(64%)]	Train Loss: 1.114893
# Train Epoch: 1 [38400/50000(77%)]	Train Loss: 1.323007
# Train Epoch: 1 [44800/50000(90%)]	Train Loss: 1.207602
#
# [EPOCH: 1], 	Test Loss: 0.0319, 	Test Accuracy: 62.41 %
#
# Train Epoch: 2 [0/50000(0%)]	Train Loss: 1.147233
# Train Epoch: 2 [6400/50000(13%)]	Train Loss: 0.896270
# Train Epoch: 2 [12800/50000(26%)]	Train Loss: 1.162779
# Train Epoch: 2 [19200/50000(38%)]	Train Loss: 0.664710
# Train Epoch: 2 [25600/50000(51%)]	Train Loss: 0.925878
# Train Epoch: 2 [32000/50000(64%)]	Train Loss: 1.002215
# Train Epoch: 2 [38400/50000(77%)]	Train Loss: 0.983502
# Train Epoch: 2 [44800/50000(90%)]	Train Loss: 0.883339
#
# [EPOCH: 2], 	Test Loss: 0.0265, 	Test Accuracy: 70.47 %
#
# Train Epoch: 3 [0/50000(0%)]	Train Loss: 1.102839
# Train Epoch: 3 [6400/50000(13%)]	Train Loss: 0.777384
# Train Epoch: 3 [12800/50000(26%)]	Train Loss: 0.730736
# Train Epoch: 3 [19200/50000(38%)]	Train Loss: 0.402618
# Train Epoch: 3 [25600/50000(51%)]	Train Loss: 0.807414
# Train Epoch: 3 [32000/50000(64%)]	Train Loss: 0.732025
# Train Epoch: 3 [38400/50000(77%)]	Train Loss: 0.610072
# Train Epoch: 3 [44800/50000(90%)]	Train Loss: 0.650848
#
# [EPOCH: 3], 	Test Loss: 0.0227, 	Test Accuracy: 74.98 %
#
# Train Epoch: 4 [0/50000(0%)]	Train Loss: 0.538007
# Train Epoch: 4 [6400/50000(13%)]	Train Loss: 1.153187
# Train Epoch: 4 [12800/50000(26%)]	Train Loss: 0.562069
# Train Epoch: 4 [19200/50000(38%)]	Train Loss: 0.717430
# Train Epoch: 4 [25600/50000(51%)]	Train Loss: 0.935992
# Train Epoch: 4 [32000/50000(64%)]	Train Loss: 0.582194
# Train Epoch: 4 [38400/50000(77%)]	Train Loss: 0.609343
# Train Epoch: 4 [44800/50000(90%)]	Train Loss: 0.402774
#
# [EPOCH: 4], 	Test Loss: 0.0215, 	Test Accuracy: 76.27 %
#
# Train Epoch: 5 [0/50000(0%)]	Train Loss: 0.711619
# Train Epoch: 5 [6400/50000(13%)]	Train Loss: 0.554374
# Train Epoch: 5 [12800/50000(26%)]	Train Loss: 0.527876
# Train Epoch: 5 [19200/50000(38%)]	Train Loss: 0.708992
# Train Epoch: 5 [25600/50000(51%)]	Train Loss: 0.420762
# Train Epoch: 5 [32000/50000(64%)]	Train Loss: 0.594983
# Train Epoch: 5 [38400/50000(77%)]	Train Loss: 0.620677
# Train Epoch: 5 [44800/50000(90%)]	Train Loss: 0.305406
#
# [EPOCH: 5], 	Test Loss: 0.0197, 	Test Accuracy: 78.54 %
#
# Train Epoch: 6 [0/50000(0%)]	Train Loss: 0.322443
# Train Epoch: 6 [6400/50000(13%)]	Train Loss: 0.549756
# Train Epoch: 6 [12800/50000(26%)]	Train Loss: 0.501449
# Train Epoch: 6 [19200/50000(38%)]	Train Loss: 0.606154
# Train Epoch: 6 [25600/50000(51%)]	Train Loss: 0.495905
# Train Epoch: 6 [32000/50000(64%)]	Train Loss: 0.316504
# Train Epoch: 6 [38400/50000(77%)]	Train Loss: 0.297053
# Train Epoch: 6 [44800/50000(90%)]	Train Loss: 0.444531
#
# [EPOCH: 6], 	Test Loss: 0.0188, 	Test Accuracy: 79.66 %
#
# Train Epoch: 7 [0/50000(0%)]	Train Loss: 0.490955
# Train Epoch: 7 [6400/50000(13%)]	Train Loss: 0.512385
# Train Epoch: 7 [12800/50000(26%)]	Train Loss: 0.653523
# Train Epoch: 7 [19200/50000(38%)]	Train Loss: 0.426944
# Train Epoch: 7 [25600/50000(51%)]	Train Loss: 0.634463
# Train Epoch: 7 [32000/50000(64%)]	Train Loss: 0.405381
# Train Epoch: 7 [38400/50000(77%)]	Train Loss: 0.312674
# Train Epoch: 7 [44800/50000(90%)]	Train Loss: 0.212931
#
# [EPOCH: 7], 	Test Loss: 0.0177, 	Test Accuracy: 81.05 %
#
# Train Epoch: 8 [0/50000(0%)]	Train Loss: 0.536752
# Train Epoch: 8 [6400/50000(13%)]	Train Loss: 0.344523
# Train Epoch: 8 [12800/50000(26%)]	Train Loss: 0.450574
# Train Epoch: 8 [19200/50000(38%)]	Train Loss: 0.497329
# Train Epoch: 8 [25600/50000(51%)]	Train Loss: 0.322469
# Train Epoch: 8 [32000/50000(64%)]	Train Loss: 0.426585
# Train Epoch: 8 [38400/50000(77%)]	Train Loss: 0.418520
# Train Epoch: 8 [44800/50000(90%)]	Train Loss: 0.725391
#
# [EPOCH: 8], 	Test Loss: 0.0164, 	Test Accuracy: 82.15 %
#
# Train Epoch: 9 [0/50000(0%)]	Train Loss: 0.269041
# Train Epoch: 9 [6400/50000(13%)]	Train Loss: 0.591926
# Train Epoch: 9 [12800/50000(26%)]	Train Loss: 0.433489
# Train Epoch: 9 [19200/50000(38%)]	Train Loss: 0.490336
# Train Epoch: 9 [25600/50000(51%)]	Train Loss: 0.277470
# Train Epoch: 9 [32000/50000(64%)]	Train Loss: 0.763529
# Train Epoch: 9 [38400/50000(77%)]	Train Loss: 0.394949
# Train Epoch: 9 [44800/50000(90%)]	Train Loss: 0.328777
#
# [EPOCH: 9], 	Test Loss: 0.0160, 	Test Accuracy: 82.17 %
#
# Train Epoch: 10 [0/50000(0%)]	Train Loss: 0.303614
# Train Epoch: 10 [6400/50000(13%)]	Train Loss: 0.733929
# Train Epoch: 10 [12800/50000(26%)]	Train Loss: 0.528518
# Train Epoch: 10 [19200/50000(38%)]	Train Loss: 0.271915
# Train Epoch: 10 [25600/50000(51%)]	Train Loss: 0.387484
# Train Epoch: 10 [32000/50000(64%)]	Train Loss: 0.361242
# Train Epoch: 10 [38400/50000(77%)]	Train Loss: 0.366948
# Train Epoch: 10 [44800/50000(90%)]	Train Loss: 0.163136
#
# [EPOCH: 10], 	Test Loss: 0.0157, 	Test Accuracy: 82.71 %
#
# Train Epoch: 11 [0/50000(0%)]	Train Loss: 0.428768
# Train Epoch: 11 [6400/50000(13%)]	Train Loss: 0.616242
# Train Epoch: 11 [12800/50000(26%)]	Train Loss: 0.423619
# Train Epoch: 11 [19200/50000(38%)]	Train Loss: 0.478643
# Train Epoch: 11 [25600/50000(51%)]	Train Loss: 0.344747
# Train Epoch: 11 [32000/50000(64%)]	Train Loss: 0.421228
# Train Epoch: 11 [38400/50000(77%)]	Train Loss: 0.435421
# Train Epoch: 11 [44800/50000(90%)]	Train Loss: 0.716387
#
# [EPOCH: 11], 	Test Loss: 0.0156, 	Test Accuracy: 83.22 %
#
# Train Epoch: 12 [0/50000(0%)]	Train Loss: 0.413139
# Train Epoch: 12 [6400/50000(13%)]	Train Loss: 0.281755
# Train Epoch: 12 [12800/50000(26%)]	Train Loss: 0.475477
# Train Epoch: 12 [19200/50000(38%)]	Train Loss: 0.418802
# Train Epoch: 12 [25600/50000(51%)]	Train Loss: 0.922439
# Train Epoch: 12 [32000/50000(64%)]	Train Loss: 0.189593
# Train Epoch: 12 [38400/50000(77%)]	Train Loss: 0.343980
# Train Epoch: 12 [44800/50000(90%)]	Train Loss: 0.341876
#
# [EPOCH: 12], 	Test Loss: 0.0157, 	Test Accuracy: 83.00 %
#
# Train Epoch: 13 [0/50000(0%)]	Train Loss: 0.318122
# Train Epoch: 13 [6400/50000(13%)]	Train Loss: 0.172563
# Train Epoch: 13 [12800/50000(26%)]	Train Loss: 0.308405
# Train Epoch: 13 [19200/50000(38%)]	Train Loss: 0.230185
# Train Epoch: 13 [25600/50000(51%)]	Train Loss: 0.342993
# Train Epoch: 13 [32000/50000(64%)]	Train Loss: 0.398466
# Train Epoch: 13 [38400/50000(77%)]	Train Loss: 0.215379
# Train Epoch: 13 [44800/50000(90%)]	Train Loss: 0.278006
#
# [EPOCH: 13], 	Test Loss: 0.0162, 	Test Accuracy: 82.93 %
#
# Train Epoch: 14 [0/50000(0%)]	Train Loss: 0.374782
# Train Epoch: 14 [6400/50000(13%)]	Train Loss: 0.255820
# Train Epoch: 14 [12800/50000(26%)]	Train Loss: 0.205384
# Train Epoch: 14 [19200/50000(38%)]	Train Loss: 0.427829
# Train Epoch: 14 [25600/50000(51%)]	Train Loss: 0.306569
# Train Epoch: 14 [32000/50000(64%)]	Train Loss: 0.230423
# Train Epoch: 14 [38400/50000(77%)]	Train Loss: 0.431802
# Train Epoch: 14 [44800/50000(90%)]	Train Loss: 0.276666
#
# [EPOCH: 14], 	Test Loss: 0.0145, 	Test Accuracy: 84.09 %
#
# Train Epoch: 15 [0/50000(0%)]	Train Loss: 0.240789
# Train Epoch: 15 [6400/50000(13%)]	Train Loss: 0.333409
# Train Epoch: 15 [12800/50000(26%)]	Train Loss: 0.255504
# Train Epoch: 15 [19200/50000(38%)]	Train Loss: 0.243548
# Train Epoch: 15 [25600/50000(51%)]	Train Loss: 0.330501
# Train Epoch: 15 [32000/50000(64%)]	Train Loss: 0.436160
# Train Epoch: 15 [38400/50000(77%)]	Train Loss: 0.284018
# Train Epoch: 15 [44800/50000(90%)]	Train Loss: 0.309965
#
# [EPOCH: 15], 	Test Loss: 0.0146, 	Test Accuracy: 83.77 %
#
# Train Epoch: 16 [0/50000(0%)]	Train Loss: 0.290002
# Train Epoch: 16 [6400/50000(13%)]	Train Loss: 0.269994
# Train Epoch: 16 [12800/50000(26%)]	Train Loss: 0.205057
# Train Epoch: 16 [19200/50000(38%)]	Train Loss: 0.219572
# Train Epoch: 16 [25600/50000(51%)]	Train Loss: 0.282167
# Train Epoch: 16 [32000/50000(64%)]	Train Loss: 0.447996
# Train Epoch: 16 [38400/50000(77%)]	Train Loss: 0.409513
# Train Epoch: 16 [44800/50000(90%)]	Train Loss: 0.131845
#
# [EPOCH: 16], 	Test Loss: 0.0150, 	Test Accuracy: 83.70 %
#
# Train Epoch: 17 [0/50000(0%)]	Train Loss: 0.346385
# Train Epoch: 17 [6400/50000(13%)]	Train Loss: 0.232891
# Train Epoch: 17 [12800/50000(26%)]	Train Loss: 0.304165
# Train Epoch: 17 [19200/50000(38%)]	Train Loss: 0.289072
# Train Epoch: 17 [25600/50000(51%)]	Train Loss: 0.349802
# Train Epoch: 17 [32000/50000(64%)]	Train Loss: 0.723556
# Train Epoch: 17 [38400/50000(77%)]	Train Loss: 0.361115
# Train Epoch: 17 [44800/50000(90%)]	Train Loss: 0.745343
#
# [EPOCH: 17], 	Test Loss: 0.0150, 	Test Accuracy: 84.29 %
#
# Train Epoch: 18 [0/50000(0%)]	Train Loss: 0.396583
# Train Epoch: 18 [6400/50000(13%)]	Train Loss: 0.330725
# Train Epoch: 18 [12800/50000(26%)]	Train Loss: 0.384395
# Train Epoch: 18 [19200/50000(38%)]	Train Loss: 0.226787
# Train Epoch: 18 [25600/50000(51%)]	Train Loss: 0.377938
# Train Epoch: 18 [32000/50000(64%)]	Train Loss: 0.179083
# Train Epoch: 18 [38400/50000(77%)]	Train Loss: 0.203862
# Train Epoch: 18 [44800/50000(90%)]	Train Loss: 0.116233
#
# [EPOCH: 18], 	Test Loss: 0.0157, 	Test Accuracy: 83.78 %
#
# Train Epoch: 19 [0/50000(0%)]	Train Loss: 0.142696
# Train Epoch: 19 [6400/50000(13%)]	Train Loss: 0.219753
# Train Epoch: 19 [12800/50000(26%)]	Train Loss: 0.189696
# Train Epoch: 19 [19200/50000(38%)]	Train Loss: 0.164302
# Train Epoch: 19 [25600/50000(51%)]	Train Loss: 0.262023
# Train Epoch: 19 [32000/50000(64%)]	Train Loss: 0.092414
# Train Epoch: 19 [38400/50000(77%)]	Train Loss: 0.319110
# Train Epoch: 19 [44800/50000(90%)]	Train Loss: 0.414426
#
# [EPOCH: 19], 	Test Loss: 0.0148, 	Test Accuracy: 84.74 %
#
# Train Epoch: 20 [0/50000(0%)]	Train Loss: 0.286124
# Train Epoch: 20 [6400/50000(13%)]	Train Loss: 0.188438
# Train Epoch: 20 [12800/50000(26%)]	Train Loss: 0.271031
# Train Epoch: 20 [19200/50000(38%)]	Train Loss: 0.159923
# Train Epoch: 20 [25600/50000(51%)]	Train Loss: 0.283459
# Train Epoch: 20 [32000/50000(64%)]	Train Loss: 0.291095
# Train Epoch: 20 [38400/50000(77%)]	Train Loss: 0.210923
# Train Epoch: 20 [44800/50000(90%)]	Train Loss: 0.247528
#
# [EPOCH: 20], 	Test Loss: 0.0147, 	Test Accuracy: 84.79 %

# %%
a = [2] + [1] * 2
a
# Out:
# [2, 1, 1]
